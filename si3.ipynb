# %% [markdown]
# <a href="https://colab.research.google.com/github/yashsingla984/CP-Vton-cloth-masking/blob/main/si3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load and show an image with Pillow
from PIL import Image
# load the image
image = Image.open('000001_0.jpg')
# summarize some details about the image
print(image.format)
print(image.mode)
print(image.size)
# show the image
# Out:
# JPEG
# RGB
# (192, 256)

# %%
import cv2
import numpy as np
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/My\ Drive/shopcom
img = cv2.imread('000001_0.jpg',-1) 
from google.colab.patches import cv2_imshow
# Displaying the image 
cv2_imshow( img)
#print(img.shape)
#px = img[100,100]
#print(px)

#blue = img[235,20,2]
#print(blue)



img_file = '000001_0.jpg'
img = cv2.imread(img_file, cv2.IMREAD_COLOR)           # rgb
alpha_img = cv2.imread(img_file, cv2.IMREAD_UNCHANGED) # rgba
gray_img = cv2.imread(img_file, cv2.IMREAD_GRAYSCALE)  # grayscale

print(type(img))
print('RGB shape: ', img.shape)        # Rows, cols, channels
print('ARGB shape:', alpha_img.shape)
print('Gray shape:', gray_img.shape)
print('img.dtype: ', img.dtype)
print('img.size: ', img.size)

im=np.asarray(img)
print(im)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive/shopcom
# <PIL.Image.Image image mode=RGB size=192x256 at 0x7FB9959E8A90>
# <class 'numpy.ndarray'>
# RGB shape:  (256, 192, 3)
# ARGB shape: (256, 192, 3)
# Gray shape: (256, 192)
# img.dtype:  uint8
# img.size:  147456
# [[[230 232 232]
#   [230 232 232]
#   [230 232 232]
#   ...
#   [231 234 232]
#   [231 234 232]
#   [231 234 232]]
#
#  [[230 232 232]
#   [230 232 232]
#   [230 232 232]
#   ...
#   [231 234 232]
#   [231 234 232]
#   [231 234 232]]
#
#  [[230 232 232]
#   [230 232 232]
#   [230 232 232]
#   ...
#   [231 234 232]
#   [231 234 232]
#   [231 234 232]]
#
#  ...
#
#  [[234 239 238]
#   [234 239 238]
#   [234 239 238]
#   ...
#   [225 227 227]
#   [225 227 227]
#   [225 227 227]]
#
#  [[234 239 238]
#   [234 239 238]
#   [234 239 238]
#   ...
#   [225 227 227]
#   [225 227 227]
#   [225 227 227]]
#
# ...

# %%
image.show()
